# %% [markdown]
# # Case Study On Python Basics

# %% [markdown]
# ## Question 1

# %%
# Bank Account Manager

def deposit(balance):
    try:
        amount = float(input("Enter amount to deposit: "))
        if amount <= 0:
            print("Amount must be greater than 0.")
            return balance
        balance += amount
        print(f"₹{amount} deposited successfully.")
        return balance
    except ValueError:
        print("Invalid input. Please enter a valid number.")
        return balance


def withdraw(balance):
    try:
        amount = float(input("Enter amount to withdraw: "))
        if amount <= 0:
            print("Amount must be greater than 0.")
            return balance
        if amount > balance:
            print("Insufficient balance.")
            return balance
        balance -= amount
        print(f"₹{amount} withdrawn successfully.")
        return balance
    except ValueError:
        print("Invalid input. Please enter a valid number.")
        return balance


def check_balance(balance):
    print(f"Current balance: ₹{balance}")


def show_menu():
    print("\n--- Bank Account Manager ---")
    print("1. Deposit")
    print("2. Withdraw")
    print("3. Check Balance")
    print("4. Exit")


def main():
    balance = 0.0

    while True:
        show_menu()
        choice = input("Enter your choice (1-4): ").strip()

        if choice == '1':
            balance = deposit(balance)

        elif choice == '2':
            balance = withdraw(balance)

        elif choice == '3':
            check_balance(balance)

        elif choice == '4':
            print("Thank you for using the Bank Account Manager.")
            break

        else:
            print("Invalid choice. Please select between 1 and 4.")


# Run the program
main()
# Out:
# --- Bank Account Manager ---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1-4): 1
# Enter amount to deposit: 200
# ₹200.0 deposited successfully.
#
# --- Bank Account Manager ---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1-4): 100
# Invalid choice. Please select between 1 and 4.
#
# --- Bank Account Manager ---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1-4): 3
# Current balance: ₹200.0
#
# --- Bank Account Manager ---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1-4): 1
# Enter amount to deposit: 1000
# ₹1000.0 deposited successfully.
#
# --- Bank Account Manager ---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1-4): 2000
# Invalid choice. Please select between 1 and 4.
#
# --- Bank Account Manager ---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter your choice (1-4): 3
# Current balance: ₹1200.0
#
# ...

# %% [markdown]
# ## Question 2

# %%
# Function to determine weather condition
def determine_weather(temp, humidity):
    if temp > 27 and humidity < 60:
        return "sunny"
    elif humidity > 65 and temp < 25:
        return "rainy"
    elif 22 <= temp <= 27 and 60 <= humidity <= 65:
        return "cloudy"
    else:
        return "unknown"


# Function to calculate average
def calculate_average(values):
    return sum(values) / len(values)


# Store multiple weather data
temperatures = []
humidities = []

n = int(input("Enter number of days to analyze: "))

for i in range(n):
    print(f"\nDay {i+1}")
    temp = float(input("Enter temperature (°C): "))
    hum = float(input("Enter humidity (%): "))

    temperatures.append(temp)
    humidities.append(hum)

    condition = determine_weather(temp, hum)
    print(f"Weather condition: {condition}")

    if condition == "sunny":
        print("It's a bright and sunny day!")
    elif condition == "rainy":
        print("Don't forget your umbrella.")
    elif condition == "cloudy":
        print("It might be a bit gloomy.")
    else:
        print("Weather condition is not clearly defined.")


# Calculate averages
avg_temp = calculate_average(temperatures)
avg_humidity = calculate_average(humidities)

print("\n--- Weather Analysis Summary ---")
print(f"Average Temperature: {avg_temp:.2f}°C")
print(f"Average Humidity: {avg_humidity:.2f}%")
# Out:
# Enter number of days to analyze: 2
#
# Day 1
# Enter temperature (°C): 30
# Enter humidity (%): 20
# Weather condition: sunny
# It's a bright and sunny day!
#
# Day 2
# Enter temperature (°C): 20
# Enter humidity (%): 4
# Weather condition: unknown
# Weather condition is not clearly defined.
#
# --- Weather Analysis Summary ---
# Average Temperature: 25.00°C
# Average Humidity: 12.00%
